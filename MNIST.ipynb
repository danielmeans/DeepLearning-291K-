# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmeans/DeepLearning-291K-/blob/master/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tf-nightly-gpu-2.0-preview
import tensorflow as tf
# Out:
# Collecting tf-nightly-gpu-2.0-preview
#   Downloading https://files.pythonhosted.org/packages/44/26/be935e984256c702249a60a4a0a849b5a30831873527f9a12a42c6ccb70c/tf_nightly_gpu_2.0_preview-2.0.0.dev20191001-cp36-cp36m-manylinux2010_x86_64.whl (393.5MB)
#      |████████████████████████████████| 393.5MB 70kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (0.8.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (0.1.7)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (0.8.0)
# Collecting gast==0.2.2 (from tf-nightly-gpu-2.0-preview)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting tensorflow-estimator-2.0-preview (from tf-nightly-gpu-2.0-preview)
#   Downloading https://files.pythonhosted.org/packages/db/f5/790508e193121ab301cb40cada7f451c531404051ac9249f21b1f5484450/tensorflow_estimator_2.0_preview-2.0.0-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 55.4MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (3.7.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (0.33.6)
# Collecting tb-nightly<2.2.0a0,>=2.1.0a0 (from tf-nightly-gpu-2.0-preview)
#   Downloading https://files.pythonhosted.org/packages/00/94/5fb47738f1dbee78b28c1fd3a62b5512f895186eb53644f1cf0f38c42555/tb_nightly-2.1.0a20191001-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 22.7MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.11.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (1.16.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu-2.0-preview) (3.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tf-nightly-gpu-2.0-preview) (41.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.2.0a0,>=2.1.0a0->tf-nightly-gpu-2.0-preview) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.2.0a0,>=2.1.0a0->tf-nightly-gpu-2.0-preview) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tf-nightly-gpu-2.0-preview) (2.8.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=e4a068d37a8798970815b7fdfb3f436f43ba800e8007e248a798e8ee551b8730
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# Installing collected packages: gast, tensorflow-estimator-2.0-preview, tb-nightly, tf-nightly-gpu-2.0-preview
#   Found existing installation: gast 0.3.2
#     Uninstalling gast-0.3.2:
#       Successfully uninstalled gast-0.3.2
# Successfully installed gast-0.2.2 tb-nightly-2.1.0a20191001 tensorflow-estimator-2.0-preview-2.0.0 tf-nightly-gpu-2.0-preview-2.0.0.dev20191001

# %%
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# /device:GPU:0

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0 , x_test / 255.0
with tf.device('/device:GPU:0'):
  model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(units=512, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation=tf.nn.softmax)
  ])
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2196 - accuracy: 0.9349
# Epoch 2/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0965 - accuracy: 0.9707
# Epoch 3/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0697 - accuracy: 0.9776
# Epoch 4/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0523 - accuracy: 0.9837
# Epoch 5/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0445 - accuracy: 0.9855
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07015614708700886, 0.9785]
